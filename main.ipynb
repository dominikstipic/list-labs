# %%
import tifffile as tiff
import matplotlib.pyplot as plt
import numpy as np

image = tiff.imread('data/X.tiff')

# %%
plt.imshow(image[:,:,4])
plt.show()
plt.imshow(image[:,:,8])

# %%
image.shape
# Out:
# (332, 530, 13)

# %% [markdown]
# Here we have a short description of the bands which are used in the Sentinel-2 LSA.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Normalized Difference Vegetation Index
#
# It is used for the purposes of the vegation health detection.
# The area with healthy and dense vegetation health will have values closer to the 1.
# NDVI with no vegatiton will have values closer to the zero and the NDVI with the values
# to the -1 will have values closer to the -1.
#
# ### NDVI = (NIR-RED)/(NIR+RED)

# %%
X = (image[:,:,4] - image[:,:,8])/(image[:,:,4] + image[:,:,8])
X = np.nan_to_num(X)
plt.imshow(X)
plt.show()
plt.hist(X)
plt.show()
# Out:
# /tmp/ipykernel_527462/2820940216.py:1: RuntimeWarning: invalid value encountered in divide
#   X = (image[:,:,4] - image[:,:,8])/(image[:,:,4] + image[:,:,8])

# %% [markdown]
# # Normalized Difference Moisture Index
#
# Used for the moisture level detection for the vegetation.
#
# https://www.usgs.gov/landsat-missions/normalized-difference-moisture-index

# %%
Y = (image[:,:,8] - image[:,:,11])/(image[:,:,8] + image[:,:,11])
Y = np.nan_to_num(X)
plt.imshow(Y)
plt.show()
plt.hist(Y)
plt.show()
# Out:
# /tmp/ipykernel_527462/2056225693.py:1: RuntimeWarning: invalid value encountered in divide
#   Y = (image[:,:,8] - image[:,:,11])/(image[:,:,8] + image[:,:,11])

# %%
Z = ((X+Y)*1000)/2
plt.imshow(Z)

# %%
import numpy as np
from PIL import Image

img1 = Image.fromarray(X)
img1.save('out/ndvi.tiff')
img2 = Image.fromarray(Y)
img2.save('out/ndmi.tiff')

# %% [markdown]
# ## ZAD 2

# %%
import requests
import json

req = requests.get("https://plovput.li-st.net/getObjekti/")
data = json.loads(req.text)
data
# Out:
# {'type': 'FeatureCollection',
#  'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}},
#  'features': [{'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otočić Mrtovnjak',
#     'ps_br': '390',
#     'e_br': 'E3115',
#     'tip_objekta': 11,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/773.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '773'},
#    'geometry': {'type': 'Point', 'coordinates': [15.17517, 44.01113]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'kvar1',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': None,
#     'lucka_kapetanija': None,
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': None,
#     'pk': '1665'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.483333333333333, 45.46666666666667]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'test objekt vanjski operater 2',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': None,
#     'lucka_kapetanija': None,
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': None,
#     'pk': '1663'},
#    'geometry': {'type': 'Point', 'coordinates': [13.501316666666666, 45.501]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Svjetleća oznaka Premanturski školjić, E',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/Svj._oz._Premanturski_Školjić.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/19.png',
#     'pk': '1630'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.909983333333333, 44.81896666666667]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Svjetionik 4321',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 22,
#     'lucka_kapetanija': None,
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/68.png',
#     'pk': '1669'},
#    'geometry': {'type': 'Point', 'coordinates': [13.501316666666666, 45.501]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Greben Galija',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 15,
#     'lucka_kapetanija': 'Split',
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/55.png',
#     'pk': '1575'},
#    'geometry': {'type': 'Point',
#     'coordinates': [16.413383333333332, 43.531816666666664]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Donje Čelo, gradilište',
#     'ps_br': '709,2',
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/35.png',
#     'pk': '1631'},
#    'geometry': {'type': 'Point',
#     'coordinates': [18.003466666666668, 42.6796]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'test  objekt vanjski operater',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 10,
#     'lucka_kapetanija': None,
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/63.png',
#     'pk': '1662'},
#    'geometry': {'type': 'Point', 'coordinates': [13.501316666666666, 45.501]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Split, 60 m S od Gata Sv. Petra',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Split',
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/33.png',
#     'pk': '1570'},
#    'geometry': {'type': 'Point',
#     'coordinates': [16.441233333333333, 43.50403333333333]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Test kamena kula',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': None,
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/45.png',
#     'pk': '1667'},
#    'geometry': {'type': 'Point', 'coordinates': [13.501316666666666, 45.501]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Hrid Boljkovac, o. Rab',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/Sig.oz._Hrid_Boljkovac_o._Rab.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/48.png',
#     'pk': '1637'},
#    'geometry': {'type': 'Point',
#     'coordinates': [14.695666666666666, 44.8025]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rijeka Cetina',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/410.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '410'},
#    'geometry': {'type': 'Point', 'coordinates': [16.68953, 43.4373]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Verunić, br. 2',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/393.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '393'},
#    'geometry': {'type': 'Point', 'coordinates': [14.85267, 44.14255]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Fažana I',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 15,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/441.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/58.png',
#     'pk': '441'},
#    'geometry': {'type': 'Point', 'coordinates': [13.79758, 44.9254]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Fažana II',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 15,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/442.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/58.png',
#     'pk': '442'},
#    'geometry': {'type': 'Point', 'coordinates': [13.79708, 44.92408]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Čivran',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/290.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/46.png',
#     'pk': '290'},
#    'geometry': {'type': 'Point', 'coordinates': [13.56688, 45.27492]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Žontuja, S',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/1466.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/43.png',
#     'pk': '1466'},
#    'geometry': {'type': 'Point', 'coordinates': [13.57987, 45.20527]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Pličina Ceja, SW',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/1367.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/48.png',
#     'pk': '1367'},
#    'geometry': {'type': 'Point', 'coordinates': [13.92783, 44.78262]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Raša br. 5',
#     'ps_br': '142,15',
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/1542.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/35.png',
#     'pk': '1542'},
#    'geometry': {'type': 'Point',
#     'coordinates': [14.049333333333333, 45.02805]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'IVANA D',
#     'ps_br': '114,5',
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/1560.jpg',
#     'id_ais': 'IVANA D',
#     'simbol_oznaka': '/media/simboli/39.png',
#     'pk': '1560'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.264283333333333, 44.7838]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Gaženica, kontejnerski terminal, SE ugao',
#     'ps_br': '396,8',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1548.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1548'},
#    'geometry': {'type': 'Point',
#     'coordinates': [15.261216666666666, 44.08841666666667]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rt Seka, hrid 360m S',
#     'ps_br': '134',
#     'e_br': 'E2751',
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/473.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/21.png',
#     'pk': '473'},
#    'geometry': {'type': 'Point',
#     'coordinates': [14.015966666666667, 44.89391666666667]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Stara Savudrija, glava lukobrana',
#     'ps_br': '75,2',
#     'e_br': 'E2643',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/1.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1'},
#    'geometry': {'type': 'Point', 'coordinates': [13.501316666666666, 45.501]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rt Savudrija',
#     'ps_br': '75',
#     'e_br': 'E2642',
#     'tip_objekta': 10,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/935.jpg',
#     'id_ais': 'E2642 RT SAVUDRIJA',
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '935'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.490983333333332, 45.49001666666667]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otočić Palagruža',
#     'ps_br': '694',
#     'e_br': 'E3586',
#     'tip_objekta': 10,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/972.jpg',
#     'id_ais': 'E3586 OTOCIC PALAGRUZA',
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '972'},
#    'geometry': {'type': 'Point',
#     'coordinates': [16.25575, 42.392583333333334]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Lopar, glava lukobrana',
#     'ps_br': '241,2',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1532.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1532'},
#    'geometry': {'type': 'Point',
#     'coordinates': [14.722916666666666, 44.83508333333333]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Donje Čelo, glava gata',
#     'ps_br': '709,1',
#     'e_br': 'E3595,5',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/261.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '261'},
#    'geometry': {'type': 'Point', 'coordinates': [18.005, 42.67986666666667]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Ploče IV',
#     'ps_br': '651,4',
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Ploče',
#     'fotografija': 'fotografije/1551.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/64.png',
#     'pk': '1551'},
#    'geometry': {'type': 'Point',
#     'coordinates': [17.422533333333334, 43.04366666666667]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otočić Budikovac veli, W',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1473.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/46.png',
#     'pk': '1473'},
#    'geometry': {'type': 'Point', 'coordinates': [16.23772, 43.02637]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Velji Školj',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/288.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/46.png',
#     'pk': '288'},
#    'geometry': {'type': 'Point', 'coordinates': [13.57358, 45.28138]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rijeka Zrmanja, br. 60',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/374.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '374'},
#    'geometry': {'type': 'Point', 'coordinates': [15.65508, 44.20877]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rijeka Zrmanja, br. 28',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/342.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '342'},
#    'geometry': {'type': 'Point', 'coordinates': [15.62742, 44.22027]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rijeka Zrmanja, br. 68',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/382.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '382'},
#    'geometry': {'type': 'Point', 'coordinates': [15.67192, 44.20218]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otočić Budikovac veli',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1506.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/46.png',
#     'pk': '1506'},
#    'geometry': {'type': 'Point', 'coordinates': [16.23887, 43.02745]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Stobreč',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1232.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/43.png',
#     'pk': '1232'},
#    'geometry': {'type': 'Point', 'coordinates': [16.52463, 43.49742]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Raša, br. 1',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/1538.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/35.png',
#     'pk': '1538'},
#    'geometry': {'type': 'Point',
#     'coordinates': [14.047366666666667, 45.02311666666667]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Stonski kanal, plutača br. 6',
#     'ps_br': '714,8',
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/35.png',
#     'pk': '1547'},
#    'geometry': {'type': 'Point',
#     'coordinates': [17.70831666666667, 42.82568333333333]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'L.S. Brigi - Lokvice, glava lukobrana',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1543'},
#    'geometry': {'type': 'Point', 'coordinates': [16.2586, 43.5188]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Verunić, br. 4',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/394.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '394'},
#    'geometry': {'type': 'Point', 'coordinates': [14.85305, 44.14238]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Krapanj',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/397.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '397'},
#    'geometry': {'type': 'Point', 'coordinates': [15.8982, 43.68607]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Bol',
#     'ps_br': '597,5',
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/603.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/33.png',
#     'pk': '603'},
#    'geometry': {'type': 'Point', 'coordinates': [16.63393, 43.25275]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rijeka Zrmanja, br. 4',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/318.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '318'},
#    'geometry': {'type': 'Point', 'coordinates': [15.5957, 44.21193]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Ceja',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/286.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/46.png',
#     'pk': '286'},
#    'geometry': {'type': 'Point', 'coordinates': [13.92848, 44.78287]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rijeka Zrmanja, br. 22',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/336.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '336'},
#    'geometry': {'type': 'Point', 'coordinates': [15.62283, 44.22205]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rijeka Zrmanja, br. 14',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/328.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '328'},
#    'geometry': {'type': 'Point', 'coordinates': [15.61432, 44.21895]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Pelješki most, gradilište, br. 11',
#     'ps_br': '675,123',
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Ploče',
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/33.png',
#     'pk': '1457'},
#    'geometry': {'type': 'Point', 'coordinates': [17.51743, 42.92828]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Vrgada, br. 2',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1236.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/46.png',
#     'pk': '1236'},
#    'geometry': {'type': 'Point', 'coordinates': [15.50102, 43.86223]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Uvala Martinšćica, otok Cres',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1255.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/46.png',
#     'pk': '1255'},
#    'geometry': {'type': 'Point', 'coordinates': [14.4632, 44.62455]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Kanal Vlaška II',
#     'ps_br': '653,47',
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Ploče',
#     'fotografija': 'fotografije/1334.jpg',
#     'id_ais': 'VLASKA  I I BUOY',
#     'simbol_oznaka': '/media/simboli/34.png',
#     'pk': '1334'},
#    'geometry': {'type': 'Point', 'coordinates': [17.41425, 43.02683]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Sukošan, glava gata',
#     'ps_br': '399,8',
#     'e_br': 'E3170,8',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1252.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1252'},
#    'geometry': {'type': 'Point', 'coordinates': [15.30683, 44.04765]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Uvala Mala Stinica, glava trajektnog pristana',
#     'ps_br': '292,5',
#     'e_br': 'E2937',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Senj',
#     'fotografija': 'fotografije/1203.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1203'},
#    'geometry': {'type': 'Point', 'coordinates': [14.89102, 44.71938]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Ploče, terminal, N strana prilazne utvrdice',
#     'ps_br': '653,5',
#     'e_br': 'E3499,5',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Ploče',
#     'fotografija': 'fotografije/230.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '230'},
#    'geometry': {'type': 'Point', 'coordinates': [17.43125, 43.03375]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Marina Mandalina, N lukobran',
#     'ps_br': '492,3',
#     'e_br': 'E3264,5',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/1241.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1241'},
#    'geometry': {'type': 'Point', 'coordinates': [15.8942, 43.72133]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Marina Mandalina, S lukobran',
#     'ps_br': '492,4',
#     'e_br': 'E3264,8',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/1242.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1242'},
#    'geometry': {'type': 'Point', 'coordinates': [15.89613, 43.71902]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Hrid Barbaran, glava lukobrana',
#     'ps_br': '90,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/1482.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1482'},
#    'geometry': {'type': 'Point', 'coordinates': [13.58572, 45.22905]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Gaženica, otočni terminal',
#     'ps_br': '396,4',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1266.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1266'},
#    'geometry': {'type': 'Point', 'coordinates': [15.25553, 44.09453]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Luka Mandre, S ugao pristana',
#     'ps_br': '325,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1406.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1406'},
#    'geometry': {'type': 'Point', 'coordinates': [14.91925, 44.47765]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Trogir, trajektni pristan',
#     'ps_br': '540,02',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1346.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1346'},
#    'geometry': {'type': 'Point', 'coordinates': [16.2424, 43.515]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Lučica San Marino, glava gata',
#     'ps_br': '298,6',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1282.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1282'},
#    'geometry': {'type': 'Point', 'coordinates': [14.74715, 44.8228]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Uvala Koromačna, lučica Zela, glava gata',
#     'ps_br': '236,3',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1245.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1245'},
#    'geometry': {'type': 'Point', 'coordinates': [14.44825, 44.78603]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Gaženica, glava gata',
#     'ps_br': '396,6',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1291.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1291'},
#    'geometry': {'type': 'Point', 'coordinates': [15.2547, 44.09268]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Susak, S lukobran, glava',
#     'ps_br': '167,2',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1401.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1401'},
#    'geometry': {'type': 'Point', 'coordinates': [14.31152, 44.5121]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Ljubač, N lukobran, glava',
#     'ps_br': '338,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1386.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1386'},
#    'geometry': {'type': 'Point', 'coordinates': [15.29232, 44.25982]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Brodarica, glava pristana',
#     'ps_br': '473,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/1526.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1526'},
#    'geometry': {'type': 'Point', 'coordinates': [15.92003, 43.67592]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Gaženica, glavni kanal je desno',
#     'ps_br': '396,1',
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1267.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/29.png',
#     'pk': '1267'},
#    'geometry': {'type': 'Point', 'coordinates': [15.25363, 44.09455]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Mali Ždrelac III, obala kanala, most, E strana',
#     'ps_br': '417',
#     'e_br': 'E3171,73',
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1202.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/21.png',
#     'pk': '1202'},
#    'geometry': {'type': 'Point', 'coordinates': [15.2517, 44.01437]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Mali Ždrelac IV, prilazna, 230m NW od mosta',
#     'ps_br': '416',
#     'e_br': 'E3171,72',
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1199.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/19.png',
#     'pk': '1199'},
#    'geometry': {'type': 'Point', 'coordinates': [15.252, 44.01657]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Lumbarda, marina',
#     'ps_br': '643,5',
#     'e_br': 'E3485',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1384.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1384'},
#    'geometry': {'type': 'Point', 'coordinates': [17.17143, 42.92503]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Verunić, br. 1',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/391.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/48.png',
#     'pk': '391'},
#    'geometry': {'type': 'Point', 'coordinates': [14.85252, 44.1425]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Mali Ždrelac V, 450m NE od mosta',
#     'ps_br': '415',
#     'e_br': 'E3171,71',
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1200.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/21.png',
#     'pk': '1200'},
#    'geometry': {'type': 'Point', 'coordinates': [15.25602, 44.0171]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Mali Ždrelac II, obala kanala, most, W strana',
#     'ps_br': '418',
#     'e_br': 'E3171,74',
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1201.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/19.png',
#     'pk': '1201'},
#    'geometry': {'type': 'Point', 'coordinates': [15.25093, 44.01455]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Nerezine, S gat, glava',
#     'ps_br': '262',
#     'e_br': 'E3012',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1317.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1317'},
#    'geometry': {'type': 'Point', 'coordinates': [14.3991, 44.66048]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rijeka Zrmanja, br. 21',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/335.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/48.png',
#     'pk': '335'},
#    'geometry': {'type': 'Point', 'coordinates': [15.5968, 44.21538]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Mali Ždrelac I, prilazna, 180m SW od mosta',
#     'ps_br': '419',
#     'e_br': 'E3171,75',
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1198.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/19.png',
#     'pk': '1198'},
#    'geometry': {'type': 'Point', 'coordinates': [15.25033, 44.01295]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rogoznica, ribarska luka, E strana pristana',
#     'ps_br': '513,5',
#     'e_br': 'E3292,3',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/1238.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1238'},
#    'geometry': {'type': 'Point', 'coordinates': [15.96925, 43.52997]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Mlaka, Petrolejska luka, glava lukobrana',
#     'ps_br': '186',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/39.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '39'},
#    'geometry': {'type': 'Point', 'coordinates': [14.41023, 45.33307]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Batalaža, sportska lučica, glava lukobrana',
#     'ps_br': '409,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1176.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1176'},
#    'geometry': {'type': 'Point', 'coordinates': [15.21158, 44.06233]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Gaženica, glava glavnog lukobran',
#     'ps_br': '396,7',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1265.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1265'},
#    'geometry': {'type': 'Point', 'coordinates': [15.25478, 44.08895]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Seget Donji, glava pristana',
#     'ps_br': '539,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1283.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1283'},
#    'geometry': {'type': 'Point', 'coordinates': [16.22777, 43.51667]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Pučišća, E lukobran, glava',
#     'ps_br': '592,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1383.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1383'},
#    'geometry': {'type': 'Point', 'coordinates': [16.73615, 43.34832]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Kaštel Sućurac, tvornica cementa Sv. Juraj',
#     'ps_br': '549,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1512.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1512'},
#    'geometry': {'type': 'Point', 'coordinates': [16.43672, 43.54343]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Luka Batala, glava pontonskog gata',
#     'ps_br': '726,05',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1382.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1382'},
#    'geometry': {'type': 'Point', 'coordinates': [18.08672, 42.65523]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Marina Gruž, glava N lukobrana',
#     'ps_br': '726,08',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1387.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1387'},
#    'geometry': {'type': 'Point', 'coordinates': [18.07933, 42.66207]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Kanal Vlaška, 415 m SW od veza za tankere',
#     'ps_br': '653,6',
#     'e_br': None,
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Ploče',
#     'fotografija': 'fotografije/1338.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/13.png',
#     'pk': '1338'},
#    'geometry': {'type': 'Point', 'coordinates': [17.42803, 43.03087]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Supetar Vlačica, glava gata',
#     'ps_br': '587,7',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1339.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1339'},
#    'geometry': {'type': 'Point', 'coordinates': [16.5529, 43.38537]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Makarska, glava lukobrana',
#     'ps_br': '613,4',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1273.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1273'},
#    'geometry': {'type': 'Point', 'coordinates': [17.01768, 43.29217]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Jadrišćica, glava lukobrana',
#     'ps_br': '260',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1475.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1475'},
#    'geometry': {'type': 'Point', 'coordinates': [14.50518, 44.61558]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Klenovica, N lukobran, glava',
#     'ps_br': '285,3',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1400.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1400'},
#    'geometry': {'type': 'Point', 'coordinates': [14.84262, 45.10423]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Lučica Vrnaža, N  pontonski gat, glava',
#     'ps_br': '492,6',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/1416.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1416'},
#    'geometry': {'type': 'Point', 'coordinates': [15.90215, 43.72128]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Slano, ACI marina, W glava gata',
#     'ps_br': '721,4',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1328.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1328'},
#    'geometry': {'type': 'Point', 'coordinates': [17.8871, 42.78343]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Slano, ACI marina, E glava gata',
#     'ps_br': '721,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1329.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1329'},
#    'geometry': {'type': 'Point', 'coordinates': [17.88812, 42.78345]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Lučica Podvorska, glava lukobrana',
#     'ps_br': '275,6',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1365.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1365'},
#    'geometry': {'type': 'Point', 'coordinates': [14.69468, 45.16998]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Poluotok Sv. Petar, SE strana',
#     'ps_br': '612,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1272.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1272'},
#    'geometry': {'type': 'Point', 'coordinates': [17.01642, 43.2922]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Marina Vela Luka, glava gata',
#     'ps_br': '627,4',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1493.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1493'},
#    'geometry': {'type': 'Point', 'coordinates': [16.71095, 42.96027]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Tkon, trajektni pristan, NE strana',
#     'ps_br': '433,1',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1348.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1348'},
#    'geometry': {'type': 'Point', 'coordinates': [15.41878, 43.92455]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Kanal Vlaška, terminal, glava',
#     'ps_br': '653,49',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Ploče',
#     'fotografija': 'fotografije/1335.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1335'},
#    'geometry': {'type': 'Point', 'coordinates': [17.42573, 43.03132]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Kanal Vlaška, terminal, privezna utvrdica',
#     'ps_br': '653,48',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Ploče',
#     'fotografija': 'fotografije/1337.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/63.png',
#     'pk': '1337'},
#    'geometry': {'type': 'Point', 'coordinates': [17.42045, 43.02933]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Uvala Hrvatin, glava pristana',
#     'ps_br': '374,2',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1363.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1363'},
#    'geometry': {'type': 'Point', 'coordinates': [14.99635, 44.16088]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Lučica Vrnaža, S  pontonski gat, glava',
#     'ps_br': '492,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/1362.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1362'},
#    'geometry': {'type': 'Point', 'coordinates': [15.90257, 43.72107]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Luka Vir, glava gata',
#     'ps_br': '333,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1399.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1399'},
#    'geometry': {'type': 'Point', 'coordinates': [15.08483, 44.29652]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Marina Gruž, glava gata br. 1',
#     'ps_br': '726,07',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1388.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1388'},
#    'geometry': {'type': 'Point', 'coordinates': [18.08128, 42.65922]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Jelsa, glava S gata',
#     'ps_br': '610,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1402.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1402'},
#    'geometry': {'type': 'Point', 'coordinates': [16.69558, 43.16207]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otočić Ošljak, SW strana, pristan',
#     'ps_br': '408,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1504.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1504'},
#    'geometry': {'type': 'Point', 'coordinates': [15.2067, 44.07602]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Mrljane, glava lukobrana',
#     'ps_br': '419,8',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1525.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1525'},
#    'geometry': {'type': 'Point', 'coordinates': [15.35612, 43.96973]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Marina Rovinj, glava lukobrana',
#     'ps_br': '103',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/1408.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1408'},
#    'geometry': {'type': 'Point', 'coordinates': [13.63352, 45.07635]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Marina Rovinj, W glava valobrana',
#     'ps_br': '103,3',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/1409.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1409'},
#    'geometry': {'type': 'Point', 'coordinates': [13.63418, 45.0765]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Marina Rovinj, E glava valobrana',
#     'ps_br': '103,4',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/1410.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1410'},
#    'geometry': {'type': 'Point', 'coordinates': [13.63583, 45.07737]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Sv. Filip i Jakov,glava W lukobrana',
#     'ps_br': '426,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1524.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1524'},
#    'geometry': {'type': 'Point', 'coordinates': [15.4231, 43.96052]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rovenska, glava pristana',
#     'ps_br': '264,2',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1513.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1513'},
#    'geometry': {'type': 'Point', 'coordinates': [14.5072, 44.52038]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Luka Vrboska',
#     'ps_br': '607,5',
#     'e_br': None,
#     'tip_objekta': 14,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/1486.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/33.png',
#     'pk': '1486'},
#    'geometry': {'type': 'Point', 'coordinates': [16.68963, 43.17708]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Cres, W lukobran, glava',
#     'ps_br': '154,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1529.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '1529'},
#    'geometry': {'type': 'Point', 'coordinates': [14.40802, 44.95742]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rijeka Zrmanja, br. 16',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/330.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '330'},
#    'geometry': {'type': 'Point', 'coordinates': [15.61517, 44.21872]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Kanal Vlaška, 110m S od veza za tankere',
#     'ps_br': '653,662',
#     'e_br': None,
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Ploče',
#     'fotografija': 'fotografije/1550.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/13.png',
#     'pk': '1550'},
#    'geometry': {'type': 'Point', 'coordinates': [17.43195, 43.03285]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Uvala Lamjana vela, glava lukobrana',
#     'ps_br': '410,6',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1500.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1500'},
#    'geometry': {'type': 'Point', 'coordinates': [15.20263, 44.0442]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Gajdaruša',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/287.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '287'},
#    'geometry': {'type': 'Point', 'coordinates': [13.9208, 44.7888]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Mošćenička Draga, SE ugao pristana',
#     'ps_br': '176',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1530.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1530'},
#    'geometry': {'type': 'Point', 'coordinates': [14.25665, 45.23782]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Prolaz Proversa Vela IV',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 23,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1196.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/49.png',
#     'pk': '1196'},
#    'geometry': {'type': 'Point', 'coordinates': [15.23212, 43.87593]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Povile, glava lukobrana',
#     'ps_br': '279,8',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/1531.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1531'},
#    'geometry': {'type': 'Point', 'coordinates': [14.81947, 45.11545]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Kanal Vlaška, 230m SW od veza za tankere',
#     'ps_br': '653,661',
#     'e_br': None,
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Ploče',
#     'fotografija': 'fotografije/1549.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/13.png',
#     'pk': '1549'},
#    'geometry': {'type': 'Point', 'coordinates': [17.42992, 43.03182]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Uvala Luka (Porto Uš), glava plutajućeg valobrana',
#     'ps_br': '638,7',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1533.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '1533'},
#    'geometry': {'type': 'Point', 'coordinates': [17.1404, 42.95328]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Uvala Lamjana vela, glava gata',
#     'ps_br': '410,5',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1501.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1501'},
#    'geometry': {'type': 'Point', 'coordinates': [15.19987, 44.0475]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Trpanj, pješački most NE strana',
#     'ps_br': '672,3',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1534.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/63.png',
#     'pk': '1534'},
#    'geometry': {'type': 'Point', 'coordinates': [17.26933, 43.0109]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Trpanj, pješački most SW strana',
#     'ps_br': '672,4',
#     'e_br': None,
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1535.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/63.png',
#     'pk': '1535'},
#    'geometry': {'type': 'Point', 'coordinates': [17.26933, 43.0109]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Lim',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 15,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/438.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/55.png',
#     'pk': '438'},
#    'geometry': {'type': 'Point', 'coordinates': [13.58772, 45.12603]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rijeka Zrmanja, br. 46',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/360.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/47.png',
#     'pk': '360'},
#    'geometry': {'type': 'Point', 'coordinates': [15.64775, 44.21523]}},
#   {'type': 'Feature',
# ...
#    'geometry': {'type': 'Point', 'coordinates': [18.08572, 42.65777]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Trstenik, glava lukobrana',
#     'ps_br': '695',
#     'e_br': 'E3556',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/250.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '250'},
#    'geometry': {'type': 'Point', 'coordinates': [17.40003, 42.91563]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rt Dut',
#     'ps_br': '505',
#     'e_br': 'E3273,5',
#     'tip_objekta': 11,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/822.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '822'},
#    'geometry': {'type': 'Point', 'coordinates': [15.9197, 43.81015]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Orebić, glava lukobrana',
#     'ps_br': '641',
#     'e_br': 'E3480',
#     'tip_objekta': 11,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/901.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '901'},
#    'geometry': {'type': 'Point', 'coordinates': [17.17498, 42.97262]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Plomin, koljeno trajektnog pristana',
#     'ps_br': '145,8',
#     'e_br': 'E2798,5',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/24.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '24'},
#    'geometry': {'type': 'Point', 'coordinates': [14.17628, 45.13403]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rab, lukobran, glava',
#     'ps_br': '249',
#     'e_br': 'E2988',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/61.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '61'},
#    'geometry': {'type': 'Point', 'coordinates': [14.76313, 44.75573]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Tribunj, pristan',
#     'ps_br': '454',
#     'e_br': 'E3232',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/148.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '148'},
#    'geometry': {'type': 'Point', 'coordinates': [15.74433, 43.75317]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Kaprije, glava gata',
#     'ps_br': '460',
#     'e_br': 'E3229',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/151.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '151'},
#    'geometry': {'type': 'Point', 'coordinates': [15.70807, 43.68785]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otok Obonjan',
#     'ps_br': '465',
#     'e_br': 'E3230,5',
#     'tip_objekta': 11,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/800.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '800'},
#    'geometry': {'type': 'Point', 'coordinates': [15.7885, 43.67922]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otok Drvenik Veliki, pristan, glava',
#     'ps_br': '531',
#     'e_br': 'E3296',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/176.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '176'},
#    'geometry': {'type': 'Point', 'coordinates': [16.14488, 43.45028]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Marina, lukobran, glava',
#     'ps_br': '539',
#     'e_br': 'E3306',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/177.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '177'},
#    'geometry': {'type': 'Point', 'coordinates': [16.11552, 43.51205]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Slatine, lukobran, glava',
#     'ps_br': '543',
#     'e_br': 'E3314',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/178.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '178'},
#    'geometry': {'type': 'Point', 'coordinates': [16.34027, 43.49963]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Supetar, vanjski lukobran, glava',
#     'ps_br': '589',
#     'e_br': 'E3366,2',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/204.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '204'},
#    'geometry': {'type': 'Point', 'coordinates': [16.55453, 43.38667]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Hrid Krava',
#     'ps_br': '518',
#     'e_br': 'E3434',
#     'tip_objekta': 11,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/827.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '827'},
#    'geometry': {'type': 'Point', 'coordinates': [16.2191, 43.07797]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Splitska, E rt na ulazu',
#     'ps_br': '590',
#     'e_br': 'E3368',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/205.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '205'},
#    'geometry': {'type': 'Point', 'coordinates': [16.60585, 43.38058]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Povlja, E strana ulaza',
#     'ps_br': '593',
#     'e_br': 'E3384',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/207.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '207'},
#    'geometry': {'type': 'Point', 'coordinates': [16.83143, 43.34058]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Sumartin, glava lukobrana',
#     'ps_br': '596',
#     'e_br': 'E3398',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/208.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '208'},
#    'geometry': {'type': 'Point', 'coordinates': [16.87115, 43.28488]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Bol, glava lukobrana',
#     'ps_br': '597',
#     'e_br': 'E3400',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/209.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '209'},
#    'geometry': {'type': 'Point', 'coordinates': [16.65752, 43.26085]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Božava, Rt Sv. Nedjelja',
#     'ps_br': '375',
#     'e_br': 'E3100',
#     'tip_objekta': 11,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/761.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '761'},
#    'geometry': {'type': 'Point', 'coordinates': [14.91148, 44.14208]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Vira, Rt Nezadovoljan',
#     'ps_br': '600',
#     'e_br': 'E3412,4',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/212.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '212'},
#    'geometry': {'type': 'Point', 'coordinates': [16.42935, 43.19428]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Rt Sv. Eufemija',
#     'ps_br': '99',
#     'e_br': 'E2680',
#     'tip_objekta': 11,
#     'lucka_kapetanija': 'Pula',
#     'fotografija': 'fotografije/634.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '634'},
#    'geometry': {'type': 'Point', 'coordinates': [13.62947, 45.08333]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Lovišće, rt na E strani ulaza',
#     'ps_br': '623',
#     'e_br': 'E3448',
#     'tip_objekta': 11,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/890.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '890'},
#    'geometry': {'type': 'Point', 'coordinates': [16.70205, 43.0973]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Sutivan, glava lukobrana',
#     'ps_br': '587',
#     'e_br': 'E3364',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/202.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '202'},
#    'geometry': {'type': 'Point', 'coordinates': [16.47853, 43.38652]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Luka Korčula, E luka, NE ugao pristana',
#     'ps_br': '638',
#     'e_br': 'E3477',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/245.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '245'},
#    'geometry': {'type': 'Point', 'coordinates': [17.13693, 42.9605]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Kanal Ježevica, trajektni pristan',
#     'ps_br': '639',
#     'e_br': 'E3479',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/247.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '247'},
#    'geometry': {'type': 'Point', 'coordinates': [17.15072, 42.9527]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Ubli, N ugao pristana',
#     'ps_br': '685',
#     'e_br': 'E3546',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/249.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '249'},
#    'geometry': {'type': 'Point', 'coordinates': [16.82455, 42.746]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otok Šipan, Šipanska Luka',
#     'ps_br': '705',
#     'e_br': 'E3578',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/258.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '258'},
#    'geometry': {'type': 'Point', 'coordinates': [17.86053, 42.72908]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Skrivena luka, Rt Stražica',
#     'ps_br': '691',
#     'e_br': 'E3545',
#     'tip_objekta': 11,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/909.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '909'},
#    'geometry': {'type': 'Point', 'coordinates': [16.8859, 42.73023]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Račišće, glava lukobrana',
#     'ps_br': '631,5',
#     'e_br': 'E3468',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/242.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '242'},
#    'geometry': {'type': 'Point', 'coordinates': [17.01968, 42.97397]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Kučišće, glava gata',
#     'ps_br': '636,5',
#     'e_br': 'E3470,5',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/243.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '243'},
#    'geometry': {'type': 'Point', 'coordinates': [17.11558, 42.97983]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Korčula, marina, glava lukobrana',
#     'ps_br': '638,5',
#     'e_br': 'E3479,5',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/246.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '246'},
#    'geometry': {'type': 'Point', 'coordinates': [17.13785, 42.95775]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otok Prvić, Rt Stražica',
#     'ps_br': '240',
#     'e_br': 'E2887',
#     'tip_objekta': 9,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/685.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '685'},
#    'geometry': {'type': 'Point', 'coordinates': [14.76847, 44.93308]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Prapratno, glava trajektnog pristana',
#     'ps_br': '697,4',
#     'e_br': 'E3560,5',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/252.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '252'},
#    'geometry': {'type': 'Point', 'coordinates': [17.67818, 42.81105]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Hrid Karavanić',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Senj',
#     'fotografija': 'fotografije/1355.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/45.png',
#     'pk': '1355'},
#    'geometry': {'type': 'Point', 'coordinates': [14.9907, 44.51653]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otočić Sparešnjak, SW rub',
#     'ps_br': '374,6',
#     'e_br': None,
#     'tip_objekta': 11,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/1470.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '1470'},
#    'geometry': {'type': 'Point', 'coordinates': [14.95163, 44.13575]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Krastovica, E',
#     'ps_br': None,
#     'e_br': None,
#     'tip_objekta': 13,
#     'lucka_kapetanija': 'Dubrovnik',
#     'fotografija': 'fotografije/1249.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/42.png',
#     'pk': '1249'},
#    'geometry': {'type': 'Point', 'coordinates': [17.17283, 42.9393]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Stari Grad, W pristan, glava',
#     'ps_br': '602,2',
#     'e_br': 'E3413,1',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': '',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/1.png',
#     'pk': '215'},
#    'geometry': {'type': 'Point', 'coordinates': [16.57508, 43.1822]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Porozina, glava gata',
#     'ps_br': '150',
#     'e_br': 'E2801',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Rijeka',
#     'fotografija': 'fotografije/26.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '26'},
#    'geometry': {'type': 'Point', 'coordinates': [14.28467, 45.13108]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Otočić Sikavac Mali',
#     'ps_br': '338',
#     'e_br': 'E3087',
#     'tip_objekta': 12,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/504.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/19.png',
#     'pk': '504'},
#    'geometry': {'type': 'Point', 'coordinates': [15.23772, 44.29547]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Pag, S gat, glava',
#     'ps_br': '309',
#     'e_br': 'E2954',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/84.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '84'},
#    'geometry': {'type': 'Point', 'coordinates': [15.05268, 44.44405]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Ražanac, glava lukobrana',
#     'ps_br': '316',
#     'e_br': 'E2966',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Zadar',
#     'fotografija': 'fotografije/87.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '87'},
#    'geometry': {'type': 'Point', 'coordinates': [15.34747, 44.28463]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Hramina, glava lukobrana',
#     'ps_br': '438',
#     'e_br': 'E3206',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Šibenik',
#     'fotografija': 'fotografije/140.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/2.png',
#     'pk': '140'},
#    'geometry': {'type': 'Point', 'coordinates': [15.59037, 43.82323]}},
#   {'type': 'Feature',
#    'properties': {'naziv_objekta': 'Luka Vis, Prirovo',
#     'ps_br': '520',
#     'e_br': 'E3438',
#     'tip_objekta': 16,
#     'lucka_kapetanija': 'Split',
#     'fotografija': 'fotografije/171.jpg',
#     'id_ais': None,
#     'simbol_oznaka': '/media/simboli/3.png',
#     'pk': '171'},
#    'geometry': {'type': 'Point', 'coordinates': [16.18912, 43.06173]}},
#   ...]}

# %%
import json

with open("out/data.geojson", 'w') as json_file:
    json.dump(data, json_file, indent=4)

# %% [markdown]
# We have 1220 maritime objects in our dataset.
# Maritime objects are the sea ​​buoys rearranged accross the coast.
#
# ![image.png](attachment:image.png)
#
#
# It is used for mooring the ships.

# %% [markdown]
# # Machine learning
#
# Features:
# * X,Y,Z : pixels
# * NIR (near-infra red):
# * ndvi (normalized differnece vegetation index)
# * ndwi (normalized difference water index)
# * masvi2 (Modified Atmospherically Resistant Vegetation Index 2)
# * mtvi2 (Modified Atmospherically Resistant Vegetation Index 2)
# * vari (Visible Atmospherically Resistant Index) (VARI)
# * tgi (Triangular greenness index)

# %%
import pandas as pd
import sklearn 

df = pd.read_csv("data/training_data.csv")
X = df[["Red", "Green", "Blue", "NIR", "ndvi", "ndwi", "msavi2", "mtvi2", "vari", "tgi"]].to_numpy()
y = df["Class"].to_numpy()

# %% [markdown]
# # Models
#
# * K-nearest neighbors
# * XGBoost
# * RandomForest
# * Nerual network
# * Statistical vector machine
# * Decission tree
# * Linear discriminat analysis
# * Random Forest

# %%
#plt.hist(X[:,4],bins=30)
def normalize(X):
    N,M = X.shape
    Y = np.zeros([N,M])
    for i in range(M):
        xs = X[:,i]
        xs = (xs - xs.mean()) / xs.std()
        Y[:,i] = xs
    return Y

def vizualize_features(X):
    fig, axes = plt.subplots(2, 5, figsize=(25, 5))
    fig.suptitle("Normalized Distributions", fontsize=20)    
    for i in range(2):
        for j in range(5):
            index = j + 5*i
            xs = X[:, index]
            axes[i, j].hist(xs, edgecolor='black', color="red", bins=30)
            axes[i, j].grid(True)

Y = normalize(X)
vizualize_features(Y)
plt.subplots_adjust(hspace=0.5)

# %%
from functools import reduce

def fact(n):
    xs = [x for x in range(1,n+1)]
    return reduce(lambda x,y:x*y, xs)

def n_choose_k(n, k):
    return int(fact(n)/(fact(n-k)*fact(k)))

n_choose_k(10,2)
# Out:
# 45

# %%
def scatter_plot(X, cols):
    for i in range(9):
        num = 10 - i - 1
        _, axs = plt.subplots(1, num, figsize=(60, 10))
        for j in range(i+1, 10):
            index = j - i - 1
            if num != 1:
                col_a, col_b = cols[i], cols[j]
                axs[index].scatter(X[:, i], X[:, j], color="red")
                axs[index].set_title(f'{col_a} vs. {col_b}')
                axs[index].grid(True)
            else:
                axs.scatter(X[:, i], X[:, j], color="red")
                axs.set_title(f'{col_a} vs. {col_b}')
                axs.grid(True)
    # axes[5, 2].grid(True)
    
scatter_plot(Y, df.columns)

# %% [markdown]
# * K-nearest neighbors
# * XGBoost
# * RandomForest
# * Nerual network
# * Statistical vector machine
# * Decission tree
# * Linear discriminat analysis
# * Random Forest

# %% [markdown]
# ### K-nearest neigbbors
#  - A class of the certain data point is determined by the K points closest to the observed data point.
#  - Distance measure is usually Euclid distance

# %%
from sklearn.model_selection import train_test_split  
from sklearn.neighbors import KNeighborsClassifier
from collections import Counter
X_train, X_test, y_train, y_test = train_test_split(Y, y, test_size=0.2, random_state=42) 
print(f"X_train {len(X_train)}, X_test {len(X_test)}, y_train {len(y_train)}, y_test {len(y_test)}")

print(Counter(y_train))

class_one = Counter(y_train)[1]
class_two = Counter(y_train)[2]
class_three = Counter(y_train)[3]
class_one_perc = class_one / (class_one + class_two + class_three)
class_two_perc = class_two / (class_one + class_two + class_three)
class_three_perc = class_three / (class_one + class_two + class_three)
print(class_one_perc)
print(class_two_perc)
print(class_three_perc)
# Out:
# X_train 38513, X_test 9629, y_train 38513, y_test 9629
# Counter({np.int64(1): 20379, np.int64(2): 12551, np.int64(0): 5583})
# 0.6188581840267233
# 0.3811418159732766
# 0.0

# %% [markdown]
# We have splitted our dataset into 2 parts. One part is the

# %%
model = KNeighborsClassifier(n_neighbors=7) 
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc = (y_test == y_pred).sum()/len(y_pred)
print(acc)
# Out:
# 0.9992730293903832

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[1356,    0,    1],
#        [   0, 5173,    0],
#        [   5,    1, 3093]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Neural Network Model

# %%
from torch.utils.data import DataLoader, Dataset
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F


#X = torch.from_numpy(Y) 
#y = torch.from_numpy(y)
first_batch  = int(len(X)*0.7)
second_batch = len(X) - first_batch
print(f"B1={len(X)}")
print(f"B1={first_batch} B2={second_batch}")

X_train, X_test = X[0:first_batch, :], X[first_batch:, :]
y_train, y_test = y[0:first_batch], y[first_batch:]

# %%
class GeoData(Dataset):
    def __init__(self, X, y):
        first_batch  = int(len(X)*0.7)
        self.X_train, self.X_test = X[0:first_batch, :], X[first_batch:, :]
        self.y_train, self.y_test = y[0:first_batch], y[first_batch:]

    def __len__(self):
        return len(self.X_train)

    def __getitem__(self, idx):
        return self.X_train[idx], self.y_train[idx]
    
class GeoModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(10, 512),
            nn.ReLU(),
            nn.Linear(512, 200),
            nn.ReLU(),
            nn.Linear(200, 3),
        )

    def forward(self, x):
        logits = self.linear_relu_stack(x)
        return logits

geo_dataset_train  = GeoData(X_train.float(), y_train.long())
geo_dataset_test   = GeoData(X_test.float(), y_test.long())
model = GeoModel()
train_df = DataLoader(geo_dataset_train, batch_size=64, shuffle=True)
test_df  = DataLoader(geo_dataset_test, batch_size=64, shuffle=True)
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
def evaluate(loader, model):
  model.eval()
  loss_fn = torch.nn.CrossEntropyLoss()
  with torch.no_grad():
    valid_loss = 0
    y_pred  = []
    targets = []
    for input_batch, target_batch in loader:
        logits = model(input_batch)
        loss_val = loss_fn(logits, target_batch)
        valid_loss +=  loss_val.item()
        yp = torch.argmax(F.softmax(logits,dim=1),dim=1)
        y_pred = np.append(y_pred, yp)
        targets = np.append(targets, target_batch.numpy())
    valid_loss /= len(loader)
    tp = np.logical_and((y_pred == 1), (targets == 1)).sum()
    tn = np.logical_and((y_pred == 0), (targets == 0)).sum()
    fn = np.logical_and((y_pred == 0), (targets == 1)).sum()
    fp = np.logical_and((y_pred == 1), (targets == 0)).sum()
    acc = (tp+tn)/(tp+tn+fp+fn)
    precission = tp/(tp+fp)
    recall = tp/(tp+fn)
    f = 2*(precission*recall)/(precission+recall)
    d = {"loss" : valid_loss, 
         "accuracy" : acc.item(),
         "precission" : precission.item(),
         "recall" : recall.item(),
         "f" : f.item()
    }
    C = confusion_matrix(y_pred, targets)
    print(C)
    return d

# %%
N = len(train_df)
train_losses = []
test_losses = []

for epoch in range(100):
    model.train()
    running_loss = 0
    for i, (X_batch,y_batch) in enumerate(train_df):
        model.zero_grad()
        logits = model(X_batch).double()
        loss = loss_fn(logits, y_batch.long())
        loss.backward()
        running_loss += loss
        optimizer.step()
    train_loss = running_loss / N
    print(f"train loss = {train_loss}")
    res = evaluate(test_df, model)
    print(res)
    print("*****")
    train_losses.append(running_loss)
# Out:
# train loss = 0.0003570328825127103
# [[1387    0    5]
#  [   0 5592    0]
#  [   1    0 3125]]
# {'loss': 0.013346976911194143, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 0.0016673806745379997
# [[1388    0    8]
#  [   0 5592    0]
#  [   0    0 3122]]
# {'loss': 0.004418131995814126, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 0.07710763543887754
# [[1387    0   13]
#  [   0 5592    0]
#  [   1    0 3117]]
# {'loss': 0.012544572089693298, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 0.00010078597440657654
# [[1387    0   10]
#  [   0 5592    0]
#  [   1    0 3120]]
# {'loss': 0.013195213476179458, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 7.358248799931969e-05
# [[1387    0    9]
#  [   0 5592    0]
#  [   1    0 3121]]
# {'loss': 0.014511864263101693, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 6.540362839327411e-05
# [[1387    0    9]
#  [   0 5592    0]
#  [   1    0 3121]]
# {'loss': 0.014987121685234828, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 6.383651679968486e-05
# [[1387    0    8]
#  [   0 5592    0]
#  [   1    0 3122]]
# {'loss': 0.016544793801193135, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 0.0001318667116131727
# [[1387    0   11]
#  [   0 5592    0]
#  [   1    0 3119]]
# {'loss': 0.017577771579659986, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 8.228338412503215e-05
# [[1387    0    8]
#  [   0 5592    0]
#  [   1    0 3122]]
# {'loss': 0.01835585604393401, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 0.0001295176052137444
# [[1387    0   10]
#  [   0 5592    0]
#  [   1    0 3120]]
# {'loss': 0.009887134082021291, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 0.00011281237247130829
# [[1387    0    8]
#  [   0 5592    0]
#  [   1    0 3122]]
# {'loss': 0.014247181583275962, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
# train loss = 8.001100706563691e-05
# [[1387    0    7]
#  [   0 5592    0]
#  [   1    0 3123]]
# {'loss': 0.017053850129020477, 'accuracy': 1.0, 'precission': 1.0, 'recall': 1.0, 'f': 1.0}
# *****
